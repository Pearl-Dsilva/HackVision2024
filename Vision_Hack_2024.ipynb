# %% [markdown]
# # Vision Hack 2024
# Hello, we are the Pixel Pros, and, for our Computer Vision Hackathon __Vision Hack 2024__, decided to create a Traffic Congestion Detection system using YOLO V8.
# While it is not difficult to collect data from intersections and use them as a testing input for the model, controlling traffic and its flow is not possible in a real world scenario.
# To overcome this, we used synthetic data generated using a Video Game.
#
# To do this, we:
# - Used the popular video game GTA-V to create synthetic data of an intersection for about 2 minutes.
# - In the game, there are two in-roads the video focuses on, the Left and the Right in-road.
# - We are Detecting and counting the number of cars in both the sections and determining if that segment is congested or not.
# - This can be particulary useful when we want to build an automated traffic signal that changes based on the congestion detected.
#
# Where this approach will truely be benificial is in using modifications to the game to simulate extremely rare scenarios and teach the model based on those scenarios.
#
# Done by:
# - Pearl Veola Dsilva (2347245)
# - Kenneth Dominic Fernandes (2347231)

# %%
# Required libraries
# %pip install torch ultralytics cvzone shapely
# Out:
# Requirement already satisfied: torch in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (2.5.1)
# Requirement already satisfied: ultralytics in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (8.3.43)
# Requirement already satisfied: cvzone in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (1.6.1)
# Collecting shapely
#   Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\kenne\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from ultralytics) (2.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\kenne\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kenne\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from requests>=2.23.0->ultralytics) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kenne\anaconda3\envs\computervision\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\kenne\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.4 MB 929.6 kB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.4 MB 985.5 kB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.4 MB 985.5 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 762.0 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 762.0 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 713.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 713.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 713.8 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 713.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 517.3 kB/s eta 0:00:00
# Installing collected packages: shapely
# Successfully installed shapely-2.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon
import numpy as np
import math
import cvzone

# %%
class Tracker:
    def __init__(self):
        self.center_points = {}
        self.id_count = 0


    def update(self, objects_rect):
        objects_bbs_ids = []

        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            same_object_detected = False
            for id, pt in self.center_points.items():
                dist = math.hypot(cx - pt[0], cy - pt[1])

                if dist < 35:
                    self.center_points[id] = (cx, cy)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        self.center_points = new_center_points.copy()
        return objects_bbs_ids

# %%
# Load the YOLO model
model = YOLO('./model/yolov8s.pt')

# %%
# Create a named window and set a mouse callback function
cap = cv2.VideoCapture('./data/CV Traffic.avi')  # Initialize video capture with the video file

# %%
with open("./labels/label.txt", "r") as my_file:
    class_list = my_file.read().split("\n")  # Split the content by newline to get a list of class names

# %%
# Initialize counters and trackers
count = 0
car_count = 0
bus_count = 0
truck_count = 0
tracker = Tracker()

# %%
# initialize colors
white = (255, 255, 255)
orange = (0, 165, 255)
red = (0, 0, 255)

# initialize offset
x_shift = -250
y_shift = -100

# %%
# Define the four points of the polygon (plane)
polygon_points_left = [(1, 100), (1, 350), (400, 250), (400, 100)]
polygon_left = Polygon(polygon_points_left)  # Create a polygon object using the points
polygon_points_right = [
    (859 + x_shift, 368 + y_shift),
    (1255 + x_shift, 426 + y_shift),
    (1245 + x_shift, 204 + y_shift),
    (854 + x_shift, 206 + y_shift),
]
polygon_right = Polygon(
    polygon_points_right
)  # Create a polygon object using the points

# %%
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use 'XVID', 'MP4V', etc. based on the codec you want
out = cv2.VideoWriter('./output/output_video.mp4', fourcc, 20.0, (1020, 500))  # Change the frame size as needed

# %%
# Start processing the video frame by frame
while True:
    ret, frame = cap.read()  # Read a frame from the video
    if not ret:  # If no frame is read (end of video), break the loop
        break

    count += 1  # Increment frame count
    if count % 3 != 0:  # Process every third frame
        continue

    car_count_left = 0
    bus_count_left = 0
    truck_count_left = 0

    car_count_right = 0
    bus_count_right = 0
    truck_count_right = 0

    frame = cv2.resize(frame, (1020, 500))  # Resize the frame for consistent processing

    # Predict objects in the frame using YOLO model
    results = model.predict(frame)
    detections = results[0].boxes.data
    px = pd.DataFrame(detections).astype(
        "float"
    )

    # Initialize a list to store bounding boxes for each vehicle type
    cars, buses, trucks = [], [], []

    # Iterate over the detection results and categorize them into cars, buses, or trucks
    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if "car" in c:
            cars.append([x1, y1, x2, y2])
        elif "bus" in c:
            buses.append([x1, y1, x2, y2])
        elif "truck" in c:
            trucks.append([x1, y1, x2, y2])

    # Update tracker for each vehicle type
    cars_boxes = tracker.update(cars)
    buses_boxes = tracker.update(buses)
    trucks_boxes = tracker.update(trucks)

    # Check if the bounding box center of each vehicle is inside the polygon
    for bbox in cars_boxes + buses_boxes + trucks_boxes:
        cx = int((bbox[0] + bbox[2]) / 2)  # Vehicle center X
        cy = int((bbox[1] + bbox[3]) / 2)  # Vehicle center Y
        point = Point(cx, cy)  # Create a point object for the vehicle center

        if polygon_left.contains(point):  # Check if the center is inside the polygon
            if "car" in c:
                car_count += 1
                car_count_left += 1
            elif "bus" in c:
                bus_count += 1
                bus_count_left += 1
            elif "truck" in c:
                truck_count += 1
                truck_count_left += 1

        if polygon_right.contains(point):  # Check if the center is inside the polygon
            if "car" in c:
                car_count += 1
                car_count_right += 1
            elif "bus" in c:
                bus_count += 1
                bus_count_right += 1
            elif "truck" in c:
                truck_count += 1
                truck_count_right += 1

    total_left = car_count_left + bus_count_left + truck_count_left
    total_right = car_count_right + bus_count_right + truck_count_right

    # Draw the polygon on the frame
    pts_left = np.array(polygon_points_left, np.int32)
    pts_right = np.array(polygon_points_right, np.int32)
    cv2.polylines(
        frame,
        [pts_left],
        isClosed=True,
        color=(red if total_left > 10 else orange if total_left > 5 else white),
        thickness=2,
    )
    cv2.polylines(
        frame,
        [pts_right],
        isClosed=True,
        color=(red if total_left > 10 else orange if total_left > 5 else white),
        thickness=2,
    )

    cv2.putText(
        frame,
        f"Car count (left): {car_count_left}",
        (10, 30),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )
    cv2.putText(
        frame,
        f"Bus count (left): {bus_count_left}",
        (10, 60),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )
    cv2.putText(
        frame,
        f"Truck count (left): {truck_count_left}",
        (10, 90),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )

    cv2.putText(
        frame,
        f"Car count (right): {car_count_right}",
        (650, 30),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )

    cv2.putText(
        frame,
        f"Bus count (right): {bus_count_right}",
        (650, 60),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )

    cv2.putText(
        frame,
        f"Truck count (right): {truck_count_right}",
        (650, 90),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2,
    )

    # Draw and annotate each vehicle
    for bbox in cars_boxes + buses_boxes + trucks_boxes:
        cx = int((bbox[0] + bbox[2]) / 2)  # Vehicle center X
        cy = int((bbox[1] + bbox[3]) / 2)  # Vehicle center Y
        point = Point(cx, cy)  # Create a point object for the vehicle center

        if polygon_left.contains(point) or polygon_right.contains(point):
            cv2.rectangle(
                frame, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (255, 0, 255), 2
            )
            cvzone.putTextRect(frame, f"{bbox[4]}", (bbox[0], bbox[1]), 1, 1)

    cv2.imshow("Traffic Congestion using Synthetic Data from GTA V", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

    # Write frame to the output file
    out.write(frame)
# Out:
# 0: 320x640 9 cars, 1 truck, 145.0ms
# Speed: 1.0ms preprocess, 145.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 88.8ms
# Speed: 2.0ms preprocess, 88.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 motorcycle, 1 truck, 88.7ms
# Speed: 1.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 truck, 84.4ms
# Speed: 1.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 1 truck, 84.6ms
# Speed: 2.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 truck, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 2 trucks, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 motorcycle, 1 truck, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 motorcycle, 1 truck, 96.9ms
# Speed: 1.0ms preprocess, 96.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 2 trucks, 104.8ms
# Speed: 1.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 3 trucks, 104.7ms
# Speed: 1.0ms preprocess, 104.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 97.6ms
# Speed: 1.5ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 95.7ms
# Speed: 1.0ms preprocess, 95.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 motorcycle, 112.2ms
# Speed: 1.5ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 truck, 106.3ms
# Speed: 1.0ms preprocess, 106.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 2 trucks, 94.9ms
# Speed: 2.0ms preprocess, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 motorcycle, 3 trucks, 93.0ms
# Speed: 1.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 4 trucks, 92.6ms
# Speed: 2.1ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 4 trucks, 103.2ms
# Speed: 1.5ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 3 trucks, 95.4ms
# Speed: 2.0ms preprocess, 95.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 3 trucks, 99.8ms
# Speed: 1.0ms preprocess, 99.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 bus, 2 trucks, 98.4ms
# Speed: 1.5ms preprocess, 98.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 1 bus, 4 trucks, 102.3ms
# Speed: 1.5ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 2 buss, 6 trucks, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 bus, 5 trucks, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 motorcycle, 1 bus, 3 trucks, 89.7ms
# Speed: 1.5ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 motorcycle, 1 bus, 3 trucks, 94.1ms
# Speed: 1.0ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 motorcycle, 1 bus, 4 trucks, 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 4 trucks, 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 2 trucks, 92.9ms
# Speed: 1.0ms preprocess, 92.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 2 trucks, 1 traffic light, 97.0ms
# Speed: 2.2ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 truck, 1 traffic light, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 truck, 1 traffic light, 97.3ms
# Speed: 2.5ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 traffic light, 98.6ms
# Speed: 2.0ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 traffic light, 102.7ms
# Speed: 1.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 120.5ms
# Speed: 2.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 100.6ms
# Speed: 2.0ms preprocess, 100.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 105.5ms
# Speed: 2.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 100.9ms
# Speed: 1.0ms preprocess, 100.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 truck, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 truck, 95.9ms
# Speed: 2.0ms preprocess, 95.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 94.1ms
# Speed: 1.0ms preprocess, 94.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 90.0ms
# Speed: 1.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 94.3ms
# Speed: 1.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 90.4ms
# Speed: 1.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 90.6ms
# Speed: 1.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 87.1ms
# Speed: 1.0ms preprocess, 87.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 89.8ms
# Speed: 1.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2 trucks, 99.3ms
# Speed: 1.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2 trucks, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 2 trucks, 93.0ms
# Speed: 1.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 3 trucks, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 3 trucks, 90.2ms
# Speed: 1.5ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 97.2ms
# Speed: 1.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 89.2ms
# Speed: 1.1ms preprocess, 89.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 horse, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 horse, 95.8ms
# Speed: 1.0ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 1 horse, 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 91.9ms
# Speed: 2.0ms preprocess, 91.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 3 trucks, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 trucks, 91.2ms
# Speed: 1.5ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 2 trucks, 86.6ms
# Speed: 1.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 truck, 96.1ms
# Speed: 1.0ms preprocess, 96.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 86.8ms
# Speed: 2.0ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 traffic light, 86.3ms
# Speed: 2.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16 cars, 1 traffic light, 91.7ms
# Speed: 2.0ms preprocess, 91.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 traffic light, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 motorcycle, 1 traffic light, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 traffic light, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 traffic light, 91.3ms
# Speed: 1.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 motorcycle, 92.3ms
# Speed: 1.0ms preprocess, 92.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 traffic light, 87.8ms
# Speed: 1.0ms preprocess, 87.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 motorcycle, 1 traffic light, 91.1ms
# Speed: 1.5ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 truck, 1 traffic light, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 motorcycle, 1 truck, 1 traffic light, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 motorcycle, 1 truck, 1 traffic light, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 motorcycle, 1 truck, 1 traffic light, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 motorcycle, 1 truck, 1 traffic light, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 motorcycle, 1 truck, 1 traffic light, 102.2ms
# Speed: 2.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 1 motorcycle, 1 truck, 1 traffic light, 91.8ms
# Speed: 2.1ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 2 trucks, 1 traffic light, 87.7ms
# Speed: 2.0ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 motorcycle, 2 trucks, 1 traffic light, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 motorcycle, 2 trucks, 1 traffic light, 85.4ms
# Speed: 2.0ms preprocess, 85.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 motorcycles, 3 trucks, 1 traffic light, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 motorcycle, 1 truck, 1 traffic light, 130.7ms
# Speed: 2.5ms preprocess, 130.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 1 motorcycle, 1 truck, 1 traffic light, 90.1ms
# Speed: 1.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 motorcycle, 1 truck, 94.2ms
# Speed: 1.5ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 truck, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 95.1ms
# Speed: 2.5ms preprocess, 95.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 94.5ms
# Speed: 1.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 1 traffic light, 91.6ms
# Speed: 1.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 85.1ms
# Speed: 1.0ms preprocess, 85.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 90.2ms
# Speed: 2.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 86.9ms
# Speed: 1.5ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 94.2ms
# Speed: 2.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 89.9ms
# Speed: 1.0ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 traffic light, 87.6ms
# Speed: 2.5ms preprocess, 87.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1 traffic light, 90.0ms
# Speed: 1.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 88.3ms
# Speed: 2.0ms preprocess, 88.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 89.4ms
# Speed: 2.5ms preprocess, 89.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 1 traffic light, 84.4ms
# Speed: 1.0ms preprocess, 84.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 1 traffic light, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 1 traffic light, 87.6ms
# Speed: 1.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 1 traffic light, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 85.6ms
# Speed: 1.5ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 3 trucks, 87.3ms
# Speed: 1.5ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 89.4ms
# Speed: 2.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 91.3ms
# Speed: 1.5ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 88.6ms
# Speed: 2.0ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 3 trucks, 1 traffic light, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 94.5ms
# Speed: 1.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 91.0ms
# Speed: 1.6ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 traffic light, 87.9ms
# Speed: 1.5ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 90.6ms
# Speed: 1.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 1 traffic light, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 traffic light, 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 1 traffic light, 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 2 trucks, 1 traffic light, 87.9ms
# Speed: 2.5ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 1 traffic light, 94.4ms
# Speed: 1.0ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 traffic light, 86.6ms
# Speed: 2.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 traffic light, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 traffic light, 90.6ms
# Speed: 1.0ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 traffic light, 91.9ms
# Speed: 1.0ms preprocess, 91.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 traffic light, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 1 traffic light, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 motorcycle, 2 trucks, 1 traffic light, 92.9ms
# Speed: 1.0ms preprocess, 92.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 1 truck, 88.8ms
# Speed: 1.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 traffic light, 88.6ms
# Speed: 2.0ms preprocess, 88.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 1 truck, 88.1ms
# Speed: 2.0ms preprocess, 88.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 motorcycle, 86.2ms
# Speed: 2.0ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 86.1ms
# Speed: 1.0ms preprocess, 86.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 1 truck, 117.5ms
# Speed: 1.5ms preprocess, 117.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 7 cars, 1 motorcycle, 1 truck, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 1 truck, 87.7ms
# Speed: 2.2ms preprocess, 87.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 1 motorcycle, 1 truck, 86.4ms
# Speed: 2.5ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 2 trucks, 87.5ms
# Speed: 1.5ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 1 truck, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 89.1ms
# Speed: 2.0ms preprocess, 89.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 90.1ms
# Speed: 1.0ms preprocess, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 89.6ms
# Speed: 2.0ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 83.0ms
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 motorcycle, 1 truck, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 motorcycle, 1 truck, 90.4ms
# Speed: 1.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 87.4ms
# Speed: 1.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 motorcycle, 1 truck, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 86.8ms
# Speed: 1.0ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 86.8ms
# Speed: 1.5ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 85.6ms
# Speed: 1.5ms preprocess, 85.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 87.7ms
# Speed: 1.5ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 88.8ms
# Speed: 1.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 85.3ms
# Speed: 1.0ms preprocess, 85.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 96.3ms
# Speed: 1.0ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 85.7ms
# Speed: 1.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 86.3ms
# Speed: 1.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 82.6ms
# Speed: 1.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 88.6ms
# Speed: 1.0ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 86.0ms
# Speed: 2.4ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 85.8ms
# Speed: 2.0ms preprocess, 85.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 85.2ms
# Speed: 1.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 85.8ms
# Speed: 1.0ms preprocess, 85.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 86.2ms
# Speed: 1.0ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 85.4ms
# Speed: 1.0ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 87.4ms
# Speed: 1.0ms preprocess, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 85.6ms
# Speed: 1.5ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 85.2ms
# Speed: 2.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 81.4ms
# Speed: 1.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 86.6ms
# Speed: 1.5ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 85.6ms
# Speed: 1.0ms preprocess, 85.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 85.0ms
# Speed: 1.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 3 trucks, 1 traffic light, 85.8ms
# Speed: 2.0ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 1 traffic light, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 1 traffic light, 86.5ms
# Speed: 1.5ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 88.3ms
# Speed: 1.0ms preprocess, 88.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 87.0ms
# Speed: 1.5ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 84.9ms
# Speed: 1.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 trucks, 91.9ms
# Speed: 1.0ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 6 cars, 2 trucks, 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 90.8ms
# Speed: 1.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 85.1ms
# Speed: 2.0ms preprocess, 85.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 86.7ms
# Speed: 1.0ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 87.4ms
# Speed: 2.7ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 84.5ms
# Speed: 1.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 88.1ms
# Speed: 1.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 89.5ms
# Speed: 1.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 119.4ms
# Speed: 2.0ms preprocess, 119.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 93.3ms
# Speed: 1.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 87.3ms
# Speed: 1.0ms preprocess, 87.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 88.1ms
# Speed: 1.5ms preprocess, 88.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 86.9ms
# Speed: 2.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 2 trucks, 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 93.2ms
# Speed: 2.5ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 87.3ms
# Speed: 1.0ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 2 trucks, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 92.6ms
# Speed: 1.5ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 87.5ms
# Speed: 2.5ms preprocess, 87.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 110.9ms
# Speed: 1.9ms preprocess, 110.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 105.4ms
# Speed: 2.0ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 84.0ms
# Speed: 1.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 truck, 88.3ms
# Speed: 1.5ms preprocess, 88.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 truck, 86.6ms
# Speed: 2.0ms preprocess, 86.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 104.4ms
# Speed: 2.0ms preprocess, 104.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 89.4ms
# Speed: 2.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 87.6ms
# Speed: 2.0ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 87.3ms
# Speed: 1.5ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 8 cars, 1 motorcycle, 84.2ms
# Speed: 2.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 85.5ms
# Speed: 1.5ms preprocess, 85.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 motorcycle, 1 truck, 87.2ms
# Speed: 2.1ms preprocess, 87.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 2 trucks, 87.5ms
# Speed: 1.0ms preprocess, 87.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 2 trucks, 86.1ms
# Speed: 1.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 3 trucks, 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 83.7ms
# Speed: 1.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 skateboard, 85.3ms
# Speed: 1.6ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 90.5ms
# Speed: 1.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 84.6ms
# Speed: 2.0ms preprocess, 84.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 2 trucks, 90.1ms
# Speed: 3.1ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 86.4ms
# Speed: 1.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 85.7ms
# Speed: 1.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 85.8ms
# Speed: 1.0ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 3 trucks, 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 3 trucks, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 2 trucks, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 86.7ms
# Speed: 2.0ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 trucks, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 cars, 3 trucks, 87.0ms
# Speed: 1.5ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 trucks, 84.7ms
# Speed: 2.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 84.9ms
# Speed: 2.3ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 89.0ms
# Speed: 1.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 89.3ms
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 86.9ms
# Speed: 1.0ms preprocess, 86.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 88.6ms
# Speed: 2.0ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 84.8ms
# Speed: 1.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 buss, 1 truck, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 bus, 1 truck, 84.9ms
# Speed: 1.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 bus, 1 truck, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 90.9ms
# Speed: 2.0ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 93.6ms
# Speed: 2.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 86.2ms
# Speed: 1.0ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 89.1ms
# Speed: 2.5ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 86.6ms
# Speed: 1.0ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 buss, 1 truck, 1 traffic light, 113.6ms
# Speed: 1.0ms preprocess, 113.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 88.4ms
# Speed: 1.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 train, 1 truck, 1 traffic light, 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 truck, 1 traffic light, 90.7ms
# Speed: 1.0ms preprocess, 90.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 train, 1 truck, 1 traffic light, 89.1ms
# Speed: 1.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 90.1ms
# Speed: 1.5ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 87.3ms
# Speed: 1.0ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 truck, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 truck, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 cars, 1 bus, 1 truck, 85.6ms
# Speed: 2.5ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 89.1ms
# Speed: 2.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 88.7ms
# ...
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 95.0ms
# Speed: 2.5ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 89.3ms
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 truck, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 90.0ms
# Speed: 1.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 trucks, 1 traffic light, 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 trucks, 1 traffic light, 98.2ms
# Speed: 1.0ms preprocess, 98.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 102.9ms
# Speed: 2.0ms preprocess, 102.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 101.5ms
# Speed: 2.0ms preprocess, 101.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 1 traffic light, 102.3ms
# Speed: 2.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 bus, 1 truck, 1 traffic light, 136.9ms
# Speed: 2.0ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 bus, 1 truck, 1 traffic light, 103.2ms
# Speed: 1.5ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 1 traffic light, 104.8ms
# Speed: 1.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 bus, 1 truck, 1 traffic light, 122.2ms
# Speed: 1.0ms preprocess, 122.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 bus, 1 truck, 1 traffic light, 102.4ms
# Speed: 3.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 bus, 1 truck, 1 traffic light, 98.8ms
# Speed: 1.5ms preprocess, 98.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 truck, 1 traffic light, 114.4ms
# Speed: 1.0ms preprocess, 114.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 1 traffic light, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 1 truck, 1 traffic light, 126.3ms
# Speed: 2.5ms preprocess, 126.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 100.4ms
# Speed: 4.0ms preprocess, 100.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 106.5ms
# Speed: 2.0ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 traffic light, 103.9ms
# Speed: 3.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 truck, 1 traffic light, 104.6ms
# Speed: 2.5ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 119.8ms
# Speed: 2.5ms preprocess, 119.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 truck, 1 traffic light, 102.7ms
# Speed: 2.0ms preprocess, 102.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 bus, 2 trucks, 1 traffic light, 95.4ms
# Speed: 2.0ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 103.4ms
# Speed: 2.0ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 1 traffic light, 129.2ms
# Speed: 1.0ms preprocess, 129.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 145.6ms
# Speed: 2.0ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 truck, 1 traffic light, 127.0ms
# Speed: 1.0ms preprocess, 127.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 1 traffic light, 121.4ms
# Speed: 3.0ms preprocess, 121.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 1 traffic light, 116.1ms
# Speed: 2.0ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 113.3ms
# Speed: 2.0ms preprocess, 113.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 1 traffic light, 119.1ms
# Speed: 1.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 traffic light, 108.4ms
# Speed: 1.0ms preprocess, 108.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 1 traffic light, 105.5ms
# Speed: 1.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 106.7ms
# Speed: 1.0ms preprocess, 106.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 2 buss, 1 truck, 1 traffic light, 94.7ms
# Speed: 2.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 1 truck, 1 traffic light, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 buss, 2 trucks, 2 traffic lights, 92.7ms
# Speed: 1.0ms preprocess, 92.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 cars, 1 bus, 2 trucks, 1 traffic light, 108.4ms
# Speed: 2.0ms preprocess, 108.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 buss, 1 truck, 1 traffic light, 97.2ms
# Speed: 1.0ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 98.8ms
# Speed: 1.0ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 2 buss, 1 truck, 2 traffic lights, 96.8ms
# Speed: 2.0ms preprocess, 96.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 bus, 2 trucks, 1 traffic light, 100.3ms
# Speed: 1.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 3 buss, 1 truck, 1 traffic light, 97.6ms
# Speed: 2.0ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 2 trucks, 1 traffic light, 94.8ms
# Speed: 2.0ms preprocess, 94.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 2 trucks, 1 traffic light, 95.3ms
# Speed: 1.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 2 trucks, 2 traffic lights, 93.9ms
# Speed: 2.0ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 cars, 2 trucks, 1 traffic light, 93.2ms
# Speed: 2.0ms preprocess, 93.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 cars, 1 bus, 2 trucks, 1 traffic light, 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 cars, 1 bus, 2 trucks, 1 traffic light, 97.7ms
# Speed: 2.0ms preprocess, 97.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 18 cars, 1 bus, 3 trucks, 1 traffic light, 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 cars, 2 trucks, 1 traffic light, 91.5ms
# Speed: 1.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 18 cars, 2 trucks, 1 traffic light, 93.1ms
# Speed: 1.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 cars, 1 bus, 2 trucks, 1 traffic light, 94.9ms
# Speed: 2.0ms preprocess, 94.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 cars, 1 bus, 2 trucks, 1 traffic light, 93.2ms
# Speed: 2.1ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 cars, 2 buss, 2 trucks, 2 traffic lights, 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 90.8ms
# Speed: 2.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 bus, 2 trucks, 1 traffic light, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 bus, 1 truck, 1 traffic light, 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 90.9ms
# Speed: 1.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 bus, 1 truck, 1 traffic light, 94.6ms
# Speed: 1.0ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 bus, 1 truck, 1 traffic light, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 1 truck, 1 traffic light, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9 cars, 1 bus, 1 truck, 1 traffic light, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 1 bus, 1 truck, 1 traffic light, 94.8ms
# Speed: 2.0ms preprocess, 94.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 bus, 1 truck, 1 traffic light, 95.4ms
# Speed: 2.0ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 88.1ms
# Speed: 1.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 105.7ms
# Speed: 2.0ms preprocess, 105.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 103.6ms
# Speed: 2.0ms preprocess, 103.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 1 bus, 1 truck, 1 traffic light, 139.7ms
# Speed: 1.0ms preprocess, 139.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 1 traffic light, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 1 traffic light, 95.5ms
# Speed: 1.0ms preprocess, 95.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 89.0ms
# Speed: 2.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 97.9ms
# Speed: 2.1ms preprocess, 97.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 95.3ms
# Speed: 2.5ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 2 trucks, 1 traffic light, 107.1ms
# Speed: 2.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 95.4ms
# Speed: 2.0ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 motorcycle, 1 bus, 2 trucks, 1 traffic light, 100.3ms
# Speed: 2.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 1 traffic light, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 104.0ms
# Speed: 1.0ms preprocess, 104.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 1 truck, 1 traffic light, 97.6ms
# Speed: 2.0ms preprocess, 97.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 1 truck, 1 traffic light, 133.1ms
# Speed: 6.6ms preprocess, 133.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 89.0ms
# Speed: 2.1ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 2 trucks, 1 traffic light, 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 bus, 2 trucks, 1 traffic light, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)

# %%
out.release()
cap.release()
cv2.destroyAllWindows()
